# %%
import pandas as pd

# %%
csv_path = r'C:\Users\Shen\Documents\GitHub\pokemmo_py_auto\data\Pkdx V5.14.csv'
df = pd.read_csv(csv_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 csv_path = r'C:\Users\Shen\Documents\GitHub\pokemmo_py_auto\data\Pkdx V5.14.csv'
# ----> 2 df = pd.read_csv(csv_path)
#
# ...

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#    Per  Nat     Pokemon  HP  Atk  Def  SpA  SpD  Spe  Total  ... Egg Group II  \
# 0  1.0  1.0   Bulbasaur  45   49   49   65   65   45    318  ...        Grass
# 1  2.0  2.0     Ivysaur  60   62   63   80   80   60    405  ...        Grass
# 2  3.0  3.0    Venusaur  80   82   83  100  100   80    525  ...        Grass
# 3  4.0  4.0  Charmander  39   52   43   60   50   65    309  ...       Dragon
# 4  5.0  5.0  Charmeleon  58   64   58   80   65   80    405  ...       Dragon
#
#   Catch      EXP  Evolve Per.1 Nat.1    Joh  Hoe Sin  Un
# 0    45  1059860     NaN   1.0   1.0  226.0  NaN NaN NaN
# 1    45  1059860  Lv. 16   2.0   2.0  227.0  NaN NaN NaN
# 2    45  1059860  Lv. 32   3.0   3.0  228.0  NaN NaN NaN
# 3    45  1059860     NaN   4.0   4.0  229.0  NaN NaN NaN
# 4    45  1059860  Lv. 16   5.0   5.0  230.0  NaN NaN NaN
#
# [5 rows x 34 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Per', 'Nat', 'Pokemon', 'HP', 'Atk', 'Def', 'SpA', 'SpD', 'Spe',
#        'Total', 'Type I', 'Type II', 'Tier', 'Ability I', 'Ability II',
#        'Hidden Ability', 'Mass', 'LK/GK', 'EV Worth', 'EXPV', 'Color', 'Hatch',
#        'Gender', 'Egg Group I', 'Egg Group II', 'Catch', 'EXP', 'Evolve',
#        'Per.1', 'Nat.1', 'Joh', 'Hoe', 'Sin', 'Un'],
#       dtype='object')

# %%
columns_to_drop = ['Per.1', 'Nat.1', 'Joh', 'Hoe', 'Sin', 'Un']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
new_column_names = {
    'Per': 'Percentage',
    'Nat': 'NationalDex',
    'Pokemon': 'Pokemon',
    'HP': 'Hp',
    'Atk': 'Attack',
    'Def': 'Defense',
    'SpA': 'SpecialAttack',
    'SpD': 'SpecialDefense',
    'Spe': 'Speed',
    'Total': 'TotalStats',
    'Type I': 'Type1',
    'Type II': 'Type2',
    'Tier': 'Tier',
    'Ability I': 'Ability1',
    'Ability II': 'Ability2',
    'Hidden Ability': 'HiddenAbility',
    'Mass': 'Weight',
    'LK/GK': 'LK_GK',
    'EV Worth': 'EVWorth',
    'EXPV': 'ExperienceValue',
    'Color': 'Color',
    'Hatch': 'HatchTime',
    'Gender': 'Gender',
    'Egg Group I': 'EggGroup1',
    'Egg Group II': 'EggGroup2',
    'Catch': 'CatchRate',
    'EXP': 'Experience',
    'Evolve': 'Evolve'
}
df.rename(columns=new_column_names, inplace=True)

# %%
columns_to_drop = ['Percentage','NationalDex']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df
# Out:
#           Pokemon   Hp  Attack  Defense  SpecialAttack  SpecialDefense  Speed  \
# 0       Bulbasaur   45      49       49             65              65     45
# 1         Ivysaur   60      62       63             80              80     60
# 2        Venusaur   80      82       83            100             100     80
# 3      Charmander   39      52       43             60              50     65
# 4      Charmeleon   58      64       58             80              65     80
# ..            ...  ...     ...      ...            ...             ...    ...
# 658        Kyurem  125     130       90            130              90     95
# 659        Keldeo   91      72       90            129              90    108
# 660  Meloetta (A)  100      77       77            128             128     90
# 661  Meloetta (P)  100     128       90             77              77    128
# 662      Genesect   71     120       95            120              95     99
#
# ...

# %%
csv_path = r'C:\Users\Shen\Documents\GitHub\pokemmo_py_auto\data\Pkdx V5.14.csv'
df = pd.read_csv(csv_path)

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#    Per  Nat     Pokemon  HP  Atk  Def  SpA  SpD  Spe  Total  ... Egg Group II  \
# 0  1.0  1.0   Bulbasaur  45   49   49   65   65   45    318  ...        Grass
# 1  2.0  2.0     Ivysaur  60   62   63   80   80   60    405  ...        Grass
# 2  3.0  3.0    Venusaur  80   82   83  100  100   80    525  ...        Grass
# 3  4.0  4.0  Charmander  39   52   43   60   50   65    309  ...       Dragon
# 4  5.0  5.0  Charmeleon  58   64   58   80   65   80    405  ...       Dragon
#
#   Catch      EXP  Evolve Per.1 Nat.1    Joh  Hoe Sin  Un
# 0    45  1059860     NaN   1.0   1.0  226.0  NaN NaN NaN
# 1    45  1059860  Lv. 16   2.0   2.0  227.0  NaN NaN NaN
# 2    45  1059860  Lv. 32   3.0   3.0  228.0  NaN NaN NaN
# 3    45  1059860     NaN   4.0   4.0  229.0  NaN NaN NaN
# 4    45  1059860  Lv. 16   5.0   5.0  230.0  NaN NaN NaN
#
# [5 rows x 34 columns]

# %%
columns_to_keep = ['Pokemon', 'HP','Type I', 'Type II', 'Gender', 'Catch']
df = df[columns_to_keep]

# %%
new_column_names = {
    'Pokemon': 'Pokemon',
    'HP': 'Hp',
    'Type I': 'Type1',
    'Type II': 'Type2',
    'Gender': 'Gender',
    'Catch': 'CatchRate'
}
df.rename(columns=new_column_names, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pokemon    663 non-null    object
#  1   Hp         663 non-null    int64
#  2   Type1      663 non-null    object
#  3   Type2      306 non-null    object
#  4   Gender     663 non-null    object
#  5   CatchRate  663 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 31.2+ KB

# %%
df['Pokemon'] = df['Pokemon'].str.lower().str.replace(' ', '').str.capitalize()

# %%
# Create a new column 'Types' by combining 'Type1' and 'Type2'
df['Types'] = df['Type1'] + '/' + df['Type2'].fillna('')

# %%
# Drop the original 'Type1' and 'Type2' columns
df.drop(['Type1', 'Type2'], axis=1, inplace=True)

# %%
df
# Out:
#          Pokemon   Hp     Gender  CatchRate            Types
# 0      Bulbasaur   45  M (87.5%)         45     Grass/Poison
# 1        Ivysaur   60  M (87.5%)         45     Grass/Poison
# 2       Venusaur   80  M (87.5%)         45     Grass/Poison
# 3     Charmander   39  M (87.5%)         45            Fire/
# 4     Charmeleon   58  M (87.5%)         45            Fire/
# ..           ...  ...        ...        ...              ...
# 658       Kyurem  125       None          3       Dragon/Ice
# 659       Keldeo   91       None          3   Water/Fighting
# 660  Meloetta(a)  100       None          3   Normal/Psychic
# 661  Meloetta(p)  100       None          3  Normal/Fighting
# 662     Genesect   71       None          3        Bug/Steel
#
# [663 rows x 5 columns]

# %%
unique_genders = df['Gender'].unique()
print(unique_genders)
# Out:
# ['M (87.5%)' 'Neutral' 'F (100%)' 'M (100%)' 'F (75%)' 'M (75%)' 'None']

# %%
df['Gender'] = df['Gender'].replace('None', 0).map(lambda x: 1 if x != 0 else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pokemon    663 non-null    object
#  1   Hp         663 non-null    int64
#  2   Gender     663 non-null    int64
#  3   CatchRate  663 non-null    int64
#  4   Types      663 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 26.0+ KB

# %%
output_csv_path = r'C:\Users\Shen\Documents\GitHub\pokemmo_py_auto\data\clean_pokedex.csv'
df.to_csv(output_csv_path, index=False)

# %%
def calculate_catch_rate(max_hp=75, current_hp=1, catch_rate=255, ball_rate=1, pokemon_condition=1):
    numerator = (3 * max_hp - 2 * current_hp) * catch_rate * ball_rate * pokemon_condition
    denominator = (3 * max_hp * 255)
    final_catch_rate = numerator / denominator
    return round(final_catch_rate*100,1)




# Tuple format: (ball_name, rate, price, condition)
balls = [
    ('diveball', 2.5, 960, 'water'),
    ('pokeball', 1, 200, None),
    ('healball', 1, 340, None),
    ('greatball', 1.5, 600, None),
    ('luxuryball', 1, 610, None),
    ('premierball', 1.5, 780, None),
    ('nestball', 4, 1300, 'lv lower than 30'),
    ('timerball', 4, 1300, 'more than 10 rounds'),
    ('ultraball', 2, 1200, None),
    ('quickball', 5, 1350, 'first round'),
    ('duskball', 2.5, 1450, 'in cave or night'),
    ('netball', 2.5, 1670, 'bug or water')
]

# Example usage
catch_rate = 255
ball_rate = 1

for ball in balls:
    ball_name, rate, price, condition = ball
    final_catch_rate = calculate_catch_rate(catch_rate, ball_rate)
    print(f"Ball: {ball_name}")
    print(f"Final Catch Rate: {final_catch_rate}")
    print(f"Price: {price}")
    print(f"Condition: {condition}")
    print()
# Out:
# Ball: diveball
# Final Catch Rate: 99.7
# Price: 960
# Condition: water
#
# Ball: pokeball
# Final Catch Rate: 99.7
# Price: 200
# Condition: None
#
# Ball: healball
# Final Catch Rate: 99.7
# Price: 340
# Condition: None
#
# Ball: greatball
# Final Catch Rate: 99.7
# Price: 600
# Condition: None
#
# Ball: luxuryball
# Final Catch Rate: 99.7
# Price: 610
# Condition: None
#
# Ball: premierball
# Final Catch Rate: 99.7
# Price: 780
# Condition: None
#
# Ball: nestball
# Final Catch Rate: 99.7
# Price: 1300
# Condition: lv lower than 30
#
# Ball: timerball
# Final Catch Rate: 99.7
# Price: 1300
# Condition: more than 10 rounds
#
# Ball: ultraball
# Final Catch Rate: 99.7
# Price: 1200
# Condition: None
#
# Ball: quickball
# Final Catch Rate: 99.7
# Price: 1350
# Condition: first round
#
# Ball: duskball
# Final Catch Rate: 99.7
# Price: 1450
# Condition: in cave or night
#
# Ball: netball
# Final Catch Rate: 99.7
# Price: 1670
# Condition: bug or water

# %%
max_hp = 75
current_hp = 1
pokemon_condition = 1

# Create new columns in the DataFrame
df['poke_ball'] = calculate_catch_rate(max_hp, current_hp, df['CatchRate'], 1, pokemon_condition)
df['great_ball'] = calculate_catch_rate(max_hp, current_hp, df['CatchRate'], 1.5, pokemon_condition)
df['ultra_ball'] = calculate_catch_rate(max_hp, current_hp, df['CatchRate'], 2, pokemon_condition)
df['poke_ball_sleep'] = calculate_catch_rate(max_hp, current_hp, df['CatchRate'], 1, 2)
df['greatball_sleep'] = calculate_catch_rate(max_hp, current_hp, df['CatchRate'], 1.5, 2)
df['ultraball_sleep'] = calculate_catch_rate(max_hp, current_hp, df['CatchRate'], 2, 2)

# %%
# Define the prices
poke_ball_price = 200
great_ball_price = 600
ultra_ball_price = 1200


# Calculate the estimated money needed for 100% catch rate
df['poke_ball_money'] = (100 / df['poke_ball']) * poke_ball_price
df['great_ball_money'] = (100 / df['great_ball']) * great_ball_price
df['ultra_ball_money'] = (100 / df['ultra_ball']) * ultra_ball_price
df['poke_ball_sleep_money'] = (100 / df['poke_ball_sleep']) * poke_ball_price
df['greatball_sleep_money'] = (100/ df['greatball_sleep']) * great_ball_price
df['ultraball_sleep_money'] = (100/ df['ultraball_sleep']) * ultra_ball_price

# %%
df
# Out:
#          Pokemon   Hp  Gender  CatchRate            Types  poke_ball  \
# 0      Bulbasaur   45       1         45     Grass/Poison       17.5
# 1        Ivysaur   60       1         45     Grass/Poison       17.5
# 2       Venusaur   80       1         45     Grass/Poison       17.5
# 3     Charmander   39       1         45            Fire/       17.5
# 4     Charmeleon   58       1         45            Fire/       17.5
# ..           ...  ...     ...        ...              ...        ...
# 658       Kyurem  125       0          3       Dragon/Ice        1.2
# 659       Keldeo   91       0          3   Water/Fighting        1.2
# 660  Meloetta(a)  100       0          3   Normal/Psychic        1.2
# 661  Meloetta(p)  100       0          3  Normal/Fighting        1.2
# 662     Genesect   71       0          3        Bug/Steel        1.2
#
#      great_ball  ultra_ball  poke_ball_sleep  greatball_sleep  \
# 0          26.2        35.0             35.0             52.5
# ...

# %%
def calculate_catch_rate(max_hp=75, current_hp=1, catch_rate=255, ball_rate=1, pokemon_condition=1):
    numerator = (3 * max_hp - 2 * current_hp) * catch_rate * ball_rate * pokemon_condition
    denominator = (3 * max_hp * 255)
    final_catch_rate = numerator / denominator
    return final_catch_rate

# %%
calculate_catch_rate(catch_rate=35, ball_rate=2,pokemon_condition=2)
# Out:
# 0.5441394335511982

# %%
result=calculate_catch_rate(calculate_catch_rate=1,calculate_catch_rate=255)

# %%
df
# Out:
#          Pokemon   Hp  Gender  CatchRate            Types
# 0      Bulbasaur   45       1         45     Grass/Poison
# 1        Ivysaur   60       1         45     Grass/Poison
# 2       Venusaur   80       1         45     Grass/Poison
# 3     Charmander   39       1         45            Fire/
# 4     Charmeleon   58       1         45            Fire/
# ..           ...  ...     ...        ...              ...
# 658       Kyurem  125       0          3       Dragon/Ice
# 659       Keldeo   91       0          3   Water/Fighting
# 660  Meloetta(a)  100       0          3   Normal/Psychic
# 661  Meloetta(p)  100       0          3  Normal/Fighting
# 662     Genesect   71       0          3        Bug/Steel
#
# [663 rows x 5 columns]

# %%
def find_best_catch_rate(catch_rate, max_hp=100, ball_rates=[1, 1.5, 2], pokemon_conditions=[1, 2]):
    best_result = None

    for ball_rate in ball_rates:
        for pokemon_condition in pokemon_conditions:
            current_hp = 1  # Assuming a current HP value close to 1

            numerator = (3 * max_hp - 2 * current_hp) * catch_rate * ball_rate * pokemon_condition
            denominator = (3 * max_hp * 255)
            final_catch_rate = numerator / denominator

            if best_result is None or (final_catch_rate > best_result[1]) or (
                    final_catch_rate == best_result[1] and ball_rate < best_result[3]):
                best_result = (current_hp, final_catch_rate, pokemon_condition, ball_rate)

    return best_result


# Example usage
catch_rate = 200
max_hp = 100

best_result = find_best_catch_rate(catch_rate, max_hp, ball_rates=[1], pokemon_conditions=[2])

if best_result is not None:
    current_hp, final_catch_rate, pokemon_condition, ball_rate = best_result
    print("Best Result:")
    print("Current HP:", current_hp)
    print("Catch Rate:", final_catch_rate)
    print("Pokemon Condition:", pokemon_condition)
    print("Ball Rate:", ball_rate)
else:
    print("No combination found.")
# Out:
# Best Result:
# Current HP: 1
# Catch Rate: 1.558169934640523
# Pokemon Condition: 2
# Ball Rate: 1

# %%
def find_cheapest_catch_option(catch_rate, max_hp=100):
    ball_rate_options = [1, 1.5, 2]
    prices = {1: 200, 1.5: 600, 2: 1200}
    pokemon_conditions = [1, 2]

    cheapest_option = None
    lowest_cost = float('inf')

    for ball_rate in ball_rate_options:
        for pokemon_condition in pokemon_conditions:
            cost = prices[ball_rate]
            catch_prob = (3 * max_hp - 2) * catch_rate * ball_rate * pokemon_condition / (3 * max_hp * 255)
            if catch_prob > 0:
                cost_per_catch = cost / catch_prob
                if cost_per_catch < lowest_cost:
                    lowest_cost = cost_per_catch
                    cheapest_option = (ball_rate, pokemon_condition)

    return cheapest_option


# Example usage
catch_rate = 35
max_hp = 100

cheapest_option = find_cheapest_catch_option(catch_rate, max_hp)

if cheapest_option is not None:
    ball_rate, pokemon_condition = cheapest_option
    print("Cheapest Catch Option:")
    print("Ball Rate:", ball_rate)
    print("Pokemon Condition:", pokemon_condition)
else:
    print("No catch option available.")
# Out:
# Cheapest Catch Option:
# Ball Rate: 1
# Pokemon Condition: 2

# %%
pokemon_chinese_name="""<string id="150001">妙蛙种子</string>
<string id="150002">妙蛙草</string>
<string id="150003">妙蛙花</string>
<string id="150004">小火龙</string>
<string id="150005">火恐龙</string>
<string id="150006">喷火龙</string>
<string id="150007">杰尼龟</string>
<string id="150008">卡咪龟</string>
<string id="150009">水箭龟</string>
<string id="150010">绿毛虫</string>
<string id="150011">铁甲蛹</string>
<string id="150012">巴大蝶</string>
<string id="150013">独角虫</string>
<string id="150014">铁壳蛹</string>
<string id="150015">大针蜂</string>
<string id="150016">波波</string>
<string id="150017">比比鸟</string>
<string id="150018">大比鸟</string>
<string id="150019">小拉达</string>
<string id="150020">拉达</string>
<string id="150021">烈雀</string>
<string id="150022">大嘴雀</string>
<string id="150023">阿柏蛇</string>
<string id="150024">阿柏怪</string>
<string id="150025">皮卡丘</string>
<string id="150026">雷丘</string>
<string id="150027">穿山鼠</string>
<string id="150028">穿山王</string>
<string id="150029">尼多兰</string>
<string id="150030">尼多娜</string>
<string id="150031">尼多后</string>
<string id="150032">尼多朗</string>
<string id="150033">尼多力诺</string>
<string id="150034">尼多王</string>
<string id="150035">皮皮</string>
<string id="150036">皮可西</string>
<string id="150037">六尾</string>
<string id="150038">九尾</string>
<string id="150039">胖丁</string>
<string id="150040">胖可丁</string>
<string id="150041">超音蝠</string>
<string id="150042">大嘴蝠</string>
<string id="150043">走路草</string>
<string id="150044">臭臭花</string>
<string id="150045">霸王花</string>
<string id="150601">齿轮怪</string>
<string id="150602">麻麻小鱼</string>
<string id="150603">麻麻鳗</string>
<string id="150604">麻麻鳗鱼王</string>
<string id="150605">小灰怪</string>
<string id="150606">大宇怪</string>
<string id="150607">烛光灵</string>
<string id="150608">灯火幽灵</string>
<string id="150609">水晶灯火灵</string>
<string id="150610">牙牙</string>
<string id="150611">斧牙龙</string>
<string id="150612">双斧战龙</string>
<string id="150613">喷嚏熊</string>
<string id="150614">冻原熊</string>
<string id="150615">几何雪花</string>
<string id="150616">小嘴蜗</string>
<string id="150617">敏捷虫</string>
<string id="150618">泥巴鱼</string>
<string id="150619">功夫鼬</string>
<string id="150620">师父鼬</string>
<string id="150621">赤面龙</string>
<string id="150622">泥偶小人</string>
<string id="150623">泥偶巨人</string>
<string id="150624">驹刀小兵</string>
<string id="150625">劈斩司令</string>
<string id="150626">爆炸头水牛</string>
<string id="150627">毛头小鹰</string>
<string id="150628">勇士雄鹰</string>
<string id="150629">秃鹰丫头</string>
<string id="150630">秃鹰娜</string>
<string id="150631">熔蚁兽</string>
<string id="150632">铁蚁</string>
<string id="150633">单首龙</string>
<string id="150634">双首暴龙</string>
<string id="150635">三首恶龙</string>
<string id="150636">燃烧虫</string>
<string id="150637">火神蛾</string>
<string id="150638">勾帕路翁</string>
<string id="150639">代拉基翁</string>
<string id="150640">毕力吉翁</string>
<string id="150641">龙卷云</string>
<string id="150642">雷电云</string>
<string id="150643">莱希拉姆</string>
<string id="150644">捷克罗姆</string>
<string id="150645">土地云</string>
<string id="150646">酋雷姆</string>
<string id="150647">凯路迪欧</string>
<string id="150648">美洛耶塔</string>
<string id="150649">盖诺赛克特</string>
<string id="150650">蛋</string>
<string id="150651">蛋</string>
<string id="150652">代欧奇希斯 [速度形态]</string>
<string id="150653">结草贵妇 [砂土蓑衣]</string>
<string id="150654">结草贵妇 [垃圾蓑衣]</string>
<string id="150655">谢米 [天空形态]</string>
<string id="150656">骑拉帝纳 [起源形态]</string>
<string id="150657">洛托姆 [加热洛托姆]</string>
<string id="150658">洛托姆 [清洗洛托姆]</string>
<string id="150659">洛托姆 [结冰洛托姆]</string>
<string id="150660">洛托姆 [旋转洛托姆]</string>
<string id="150661">洛托姆 [切割洛托姆]</string>
<string id="150662">飘浮泡泡 [太阳的样子]</string>
<string id="150663">飘浮泡泡 [雨水的样子]</string>
<string id="150664">飘浮泡泡 [雪云的样子]</string>
<string id="150665">野蛮鲈鱼 [蓝条纹的样子]</string>
<string id="150666">达摩狒狒 [达摩模式]</string>
<string id="150667">美洛耶塔 [舞步形态]</string>"""

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\SS\Documents\GitHub\pokemmo_py_auto\asserts\clean_pokedex.csv')

# %%
df
# Out:
#      Unnamed: 0   No      Pokemon   Hp  Gender  CatchRate            Types
# 0             0    1    Bulbasaur   45       1         45     Grass/Poison  \
# 1             1    2      Ivysaur   60       1         45     Grass/Poison
# 2             2    3     Venusaur   80       1         45     Grass/Poison
# 3             3    4   Charmander   39       1         45            Fire/
# 4             4    5   Charmeleon   58       1         45            Fire/
# ..          ...  ...          ...  ...     ...        ...              ...
# 645         645  646       Kyurem  125       0          3       Dragon/Ice
# 646         646  647       Keldeo   91       0          3   Water/Fighting
# 647         647  648  Meloetta(a)  100       0          3   Normal/Psychic
# 648         648  649  Meloetta(p)  100       0          3  Normal/Fighting
# 649         649  650     Genesect   71       0          3        Bug/Steel
#
#      CatchMethod
# 0              3
# 1              3
# ...

# %%
import re
# 使用正则表达式提取ID和中文名字
pattern = r'<string id="(\d+)">(.*?)<\/string>'
matches = re.findall(pattern, pokemon_chinese_name)

# %%
matches
# Out:
# [('150001', '妙蛙种子'),
#  ('150002', '妙蛙草'),
#  ('150003', '妙蛙花'),
#  ('150004', '小火龙'),
#  ('150005', '火恐龙'),
#  ('150006', '喷火龙'),
#  ('150007', '杰尼龟'),
#  ('150008', '卡咪龟'),
#  ('150009', '水箭龟'),
#  ('150010', '绿毛虫'),
#  ('150011', '铁甲蛹'),
#  ('150012', '巴大蝶'),
#  ('150013', '独角虫'),
#  ('150014', '铁壳蛹'),
#  ('150015', '大针蜂'),
#  ('150016', '波波'),
#  ('150017', '比比鸟'),
#  ('150018', '大比鸟'),
#  ('150019', '小拉达'),
#  ('150020', '拉达'),
#  ('150021', '烈雀'),
#  ('150022', '大嘴雀'),
#  ('150023', '阿柏蛇'),
#  ('150024', '阿柏怪'),
#  ('150025', '皮卡丘'),
#  ('150026', '雷丘'),
#  ('150027', '穿山鼠'),
#  ('150028', '穿山王'),
#  ('150029', '尼多兰'),
#  ('150030', '尼多娜'),
#  ('150031', '尼多后'),
#  ('150032', '尼多朗'),
#  ('150033', '尼多力诺'),
#  ('150034', '尼多王'),
#  ('150035', '皮皮'),
#  ('150036', '皮可西'),
#  ('150037', '六尾'),
#  ('150038', '九尾'),
#  ('150039', '胖丁'),
#  ('150040', '胖可丁'),
#  ('150041', '超音蝠'),
#  ('150042', '大嘴蝠'),
#  ('150043', '走路草'),
#  ('150044', '臭臭花'),
#  ('150045', '霸王花'),
# ...

# %%
result = [(int(item[0][-3:]), item[1]) for item in matches]
print(result)
# Out:
# [(1, '妙蛙种子'), (2, '妙蛙草'), (3, '妙蛙花'), (4, '小火龙'), (5, '火恐龙'), (6, '喷火龙'), (7, '杰尼龟'), (8, '卡咪龟'), (9, '水箭龟'), (10, '绿毛虫'), (11, '铁甲蛹'), (12, '巴大蝶'), (13, '独角虫'), (14, '铁壳蛹'), (15, '大针蜂'), (16, '波波'), (17, '比比鸟'), (18, '大比鸟'), (19, '小拉达'), (20, '拉达'), (21, '烈雀'), (22, '大嘴雀'), (23, '阿柏蛇'), (24, '阿柏怪'), (25, '皮卡丘'), (26, '雷丘'), (27, '穿山鼠'), (28, '穿山王'), (29, '尼多兰'), (30, '尼多娜'), (31, '尼多后'), (32, '尼多朗'), (33, '尼多力诺'), (34, '尼多王'), (35, '皮皮'), (36, '皮可西'), (37, '六尾'), (38, '九尾'), (39, '胖丁'), (40, '胖可丁'), (41, '超音蝠'), (42, '大嘴蝠'), (43, '走路草'), (44, '臭臭花'), (45, '霸王花'), (46, '派拉斯'), (47, '派拉斯特'), (48, '毛球'), (49, '摩鲁蛾'), (50, '地鼠'), (51, '三地鼠'), (52, '喵喵'), (53, '猫老大'), (54, '可达鸭'), (55, '哥达鸭'), (56, '猴怪'), (57, '火暴猴'), (58, '卡蒂狗'), (59, '风速狗'), (60, '蚊香蝌蚪'), (61, '蚊香君'), (62, '蚊香泳士'), (63, '凯西'), (64, '勇基拉'), (65, '胡地'), (66, '腕力'), (67, '豪力'), (68, '怪力'), (69, '喇叭芽'), (70, '口呆花'), (71, '大食花'), (72, '玛瑙水母'), (73, '毒刺水母'), (74, '小拳石'), (75, '隆隆石'), (76, '隆隆岩'), (77, '小火马'), (78, '烈焰马'), (7
# ...

# %%
mapping = {item[0]: item[1] for item in result}

# 在数据框中添加对应元组的第二个元素
df['MatchedValue'] = df['No'].map(mapping)

print(df)
# Out:
#      Unnamed: 0   No      Pokemon   Hp  Gender  CatchRate            Types
# 0             0    1    Bulbasaur   45       1         45     Grass/Poison  \
# 1             1    2      Ivysaur   60       1         45     Grass/Poison
# 2             2    3     Venusaur   80       1         45     Grass/Poison
# 3             3    4   Charmander   39       1         45            Fire/
# 4             4    5   Charmeleon   58       1         45            Fire/
# ..          ...  ...          ...  ...     ...        ...              ...
# 645         645  646       Kyurem  125       0          3       Dragon/Ice
# 646         646  647       Keldeo   91       0          3   Water/Fighting
# 647         647  648  Meloetta(a)  100       0          3   Normal/Psychic
# 648         648  649  Meloetta(p)  100       0          3  Normal/Fighting
# 649         649  650     Genesect   71       0          3        Bug/Steel
#
# ...

# %%
df
# Out:
#      Unnamed: 0   No      Pokemon   Hp  Gender  CatchRate            Types
# 0             0    1    Bulbasaur   45       1         45     Grass/Poison  \
# 1             1    2      Ivysaur   60       1         45     Grass/Poison
# 2             2    3     Venusaur   80       1         45     Grass/Poison
# 3             3    4   Charmander   39       1         45            Fire/
# 4             4    5   Charmeleon   58       1         45            Fire/
# ..          ...  ...          ...  ...     ...        ...              ...
# 645         645  646       Kyurem  125       0          3       Dragon/Ice
# 646         646  647       Keldeo   91       0          3   Water/Fighting
# 647         647  648  Meloetta(a)  100       0          3   Normal/Psychic
# 648         648  649  Meloetta(p)  100       0          3  Normal/Fighting
# 649         649  650     Genesect   71       0          3        Bug/Steel
#
# ...

# %%
df = df.drop(['Unnamed: 0', 'ID_x', 'Chinese Name_x', 'New Column', 'ID_y', 'Chinese Name_y'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = df.drop(['Unnamed: 0', 'ID_x', 'Chinese Name_x', 'New Column', 'ID_y', 'Chinese Name_y'], axis=1)
#       2 df
#
# File c:\Users\SS\Documents\GitHub\pokemmo_py_auto\venv\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
# ...

# %%
df = df.rename(columns={'MatchedValue': 'Chinese'})

# %%
pattern = r'<string id="(\d+)">(.*?)<\/string>'
matches = re.findall(pattern, pokemon_chinese_name)

# 将提取的中文名字创建为DataFrame
chinese_name_df = pd.DataFrame(matches, columns=['ID', 'Chinese Name'])
chinese_name_df['ID'] = chinese_name_df['ID'].astype(int)

# %%
df.to_csv(r'C:\Users\SS\Documents\GitHub\pokemmo_py_auto\asserts\clean_pokedex.csv', index=False)
